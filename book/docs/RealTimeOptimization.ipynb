# %%
import os
import sys
sys.path.insert(0, os.path.abspath('..'))

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import quandl

import cvxportfolio as cp

# %% [markdown]
# ### Download data

# %%
tickers = ['AMZN', 'GOOGL', 'MCD', 'NKE']
start_date='2016-01-01'
end_date=pd.datetime.today().date()
prices = pd.DataFrame(dict([(ticker, quandl.get('WIKI/'+ticker, 
                                    start_date=start_date, 
                                    end_date=end_date)['Adj. Close'])
                for ticker in tickers]))

returns=prices.pct_change()
returns[["USDOLLAR"]]=quandl.get('FRED/DTB3', start_date=start_date, end_date=end_date)/(250*100)
returns = returns.fillna(method='ffill').iloc[1:]

# %%
returns.rolling(window=250, min_periods=250).cov()
# Out:
#                              AMZN         GOOGL           MCD           NKE  \
# Date
# 2016-01-05 AMZN               NaN           NaN           NaN           NaN
#            GOOGL              NaN           NaN           NaN           NaN
#            MCD                NaN           NaN           NaN           NaN
#            NKE                NaN           NaN           NaN           NaN
#            USDOLLAR           NaN           NaN           NaN           NaN
# 2016-01-06 AMZN               NaN           NaN           NaN           NaN
#            GOOGL              NaN           NaN           NaN           NaN
#            MCD                NaN           NaN           NaN           NaN
#            NKE                NaN           NaN           NaN           NaN
#            USDOLLAR           NaN           NaN           NaN           NaN
# 2016-01-07 AMZN               NaN           NaN           NaN           NaN
#            GOOGL              NaN           NaN           NaN           NaN
#            MCD                NaN           NaN           NaN           NaN
#            NKE                NaN           NaN           NaN           NaN
#            USDOLLAR           NaN           NaN           NaN           NaN
# 2016-01-08 AMZN               NaN           NaN           NaN           NaN
#            GOOGL              NaN           NaN           NaN           NaN
#            MCD                NaN           NaN           NaN           NaN
#            NKE                NaN           NaN           NaN           NaN
#            USDOLLAR           NaN           NaN           NaN           NaN
# 2016-01-11 AMZN               NaN           NaN           NaN           NaN
#            GOOGL              NaN           NaN           NaN           NaN
#            MCD                NaN           NaN           NaN           NaN
#            NKE                NaN           NaN           NaN           NaN
#            USDOLLAR           NaN           NaN           NaN           NaN
# 2016-01-12 AMZN               NaN           NaN           NaN           NaN
#            GOOGL              NaN           NaN           NaN           NaN
#            MCD                NaN           NaN           NaN           NaN
#            NKE                NaN           NaN           NaN           NaN
#            USDOLLAR           NaN           NaN           NaN           NaN
# ...                           ...           ...           ...           ...
# 2018-03-20 AMZN      2.166833e-04  1.062717e-04  3.613799e-05  1.486960e-05
#            GOOGL     1.062717e-04  1.489226e-04  4.260056e-05  3.795386e-05
#            MCD       3.613799e-05  4.260056e-05  1.084582e-04  1.967174e-05
#            NKE       1.486960e-05  3.795386e-05  1.967174e-05  2.299815e-04
#            USDOLLAR  9.938860e-09 -7.274711e-09 -1.276429e-08  9.735538e-09
# 2018-03-21 AMZN      2.167675e-04  1.063514e-04  3.621481e-05  1.593845e-05
#            GOOGL     1.063514e-04  1.489437e-04  4.268178e-05  3.761059e-05
#            MCD       3.621481e-05  4.268178e-05  1.085269e-04  2.085991e-05
#            NKE       1.593845e-05  3.761059e-05  2.085991e-05  2.097734e-04
#            USDOLLAR  9.627484e-09 -7.614807e-09 -1.304117e-08  4.648542e-09
# 2018-03-22 AMZN      2.195274e-04  1.102494e-04  3.737228e-05  1.946746e-05
#            GOOGL     1.102494e-04  1.541813e-04  4.430765e-05  4.358174e-05
#            MCD       3.737228e-05  4.430765e-05  1.090121e-04  2.237273e-05
#            NKE       1.946746e-05  4.358174e-05  2.237273e-05  2.106487e-04
#            USDOLLAR  7.109988e-09 -1.178746e-08 -1.411749e-08  3.703514e-09
# 2018-03-23 AMZN      2.240570e-04  1.137003e-04  3.930684e-05  1.943332e-05
#            GOOGL     1.137003e-04  1.567783e-04  4.582337e-05  4.374868e-05
#            MCD       3.930684e-05  4.582337e-05  1.097838e-04  2.210686e-05
#            NKE       1.943332e-05  4.374868e-05  2.210686e-05  2.094906e-04
#            USDOLLAR  3.790390e-09 -1.452574e-08 -1.526278e-08  4.984624e-09
# 2018-03-26 AMZN      2.298050e-04  1.176465e-04  4.214848e-05  2.227371e-05
#            GOOGL     1.176465e-04  1.594295e-04  4.776184e-05  4.581835e-05
#            MCD       4.214848e-05  4.776184e-05  1.111859e-04  2.353661e-05
#            NKE       2.227371e-05  4.581835e-05  2.353661e-05  2.106471e-04
#            USDOLLAR  7.402813e-09 -1.182069e-08 -1.342887e-08  6.305083e-09
# 2018-03-27 AMZN      2.360296e-04  1.249683e-04  4.287575e-05  2.134637e-05
#            GOOGL     1.249683e-04  1.677812e-04  4.854822e-05  4.513316e-05
#            MCD       4.287575e-05  4.854822e-05  1.112526e-04  2.353573e-05
#            NKE       2.134637e-05  4.513316e-05  2.353573e-05  2.101542e-04
#            USDOLLAR  4.171120e-09 -1.597689e-08 -1.390047e-08  7.338515e-09
#
#                          USDOLLAR
# Date
# 2016-01-05 AMZN               NaN
#            GOOGL              NaN
#            MCD                NaN
#            NKE                NaN
#            USDOLLAR           NaN
# 2016-01-06 AMZN               NaN
#            GOOGL              NaN
#            MCD                NaN
#            NKE                NaN
#            USDOLLAR           NaN
# 2016-01-07 AMZN               NaN
#            GOOGL              NaN
#            MCD                NaN
#            NKE                NaN
#            USDOLLAR           NaN
# 2016-01-08 AMZN               NaN
#            GOOGL              NaN
#            MCD                NaN
#            NKE                NaN
#            USDOLLAR           NaN
# 2016-01-11 AMZN               NaN
#            GOOGL              NaN
#            MCD                NaN
#            NKE                NaN
#            USDOLLAR           NaN
# 2016-01-12 AMZN               NaN
#            GOOGL              NaN
#            MCD                NaN
#            NKE                NaN
#            USDOLLAR           NaN
# ...                           ...
# 2018-03-20 AMZN      9.938860e-09
#            GOOGL    -7.274711e-09
#            MCD      -1.276429e-08
#            NKE       9.735538e-09
#            USDOLLAR  1.059051e-10
# 2018-03-21 AMZN      9.627484e-09
#            GOOGL    -7.614807e-09
#            MCD      -1.304117e-08
#            NKE       4.648542e-09
#            USDOLLAR  1.070183e-10
# 2018-03-22 AMZN      7.109988e-09
#            GOOGL    -1.178746e-08
#            MCD      -1.411749e-08
#            NKE       3.703514e-09
#            USDOLLAR  1.078929e-10
# 2018-03-23 AMZN      3.790390e-09
#            GOOGL    -1.452574e-08
#            MCD      -1.526278e-08
#            NKE       4.984624e-09
#            USDOLLAR  1.089637e-10
# 2018-03-26 AMZN      7.402813e-09
#            GOOGL    -1.182069e-08
#            MCD      -1.342887e-08
#            NKE       6.305083e-09
#            USDOLLAR  1.103604e-10
# 2018-03-27 AMZN      4.171120e-09
#            GOOGL    -1.597689e-08
#            MCD      -1.390047e-08
#            NKE       7.338515e-09
#            USDOLLAR  1.115554e-10
#
# [2800 rows x 5 columns]

# %%
returns.rolling(window=250, min_periods=250).cov().shift(1)
# Out:
#                              AMZN         GOOGL           MCD           NKE  \
# Date
# 2016-01-05 AMZN               NaN           NaN           NaN           NaN
#            GOOGL              NaN           NaN           NaN           NaN
#            MCD                NaN           NaN           NaN           NaN
#            NKE                NaN           NaN           NaN           NaN
#            USDOLLAR           NaN           NaN           NaN           NaN
# 2016-01-06 AMZN               NaN           NaN           NaN           NaN
#            GOOGL              NaN           NaN           NaN           NaN
#            MCD                NaN           NaN           NaN           NaN
#            NKE                NaN           NaN           NaN           NaN
#            USDOLLAR           NaN           NaN           NaN           NaN
# 2016-01-07 AMZN               NaN           NaN           NaN           NaN
#            GOOGL              NaN           NaN           NaN           NaN
#            MCD                NaN           NaN           NaN           NaN
#            NKE                NaN           NaN           NaN           NaN
#            USDOLLAR           NaN           NaN           NaN           NaN
# 2016-01-08 AMZN               NaN           NaN           NaN           NaN
#            GOOGL              NaN           NaN           NaN           NaN
#            MCD                NaN           NaN           NaN           NaN
#            NKE                NaN           NaN           NaN           NaN
#            USDOLLAR           NaN           NaN           NaN           NaN
# 2016-01-11 AMZN               NaN           NaN           NaN           NaN
#            GOOGL              NaN           NaN           NaN           NaN
#            MCD                NaN           NaN           NaN           NaN
#            NKE                NaN           NaN           NaN           NaN
#            USDOLLAR           NaN           NaN           NaN           NaN
# 2016-01-12 AMZN               NaN           NaN           NaN           NaN
#            GOOGL              NaN           NaN           NaN           NaN
#            MCD                NaN           NaN           NaN           NaN
#            NKE                NaN           NaN           NaN           NaN
#            USDOLLAR           NaN           NaN           NaN           NaN
# ...                           ...           ...           ...           ...
# 2018-03-20 AMZN      8.570287e-09 -5.452874e-09 -1.272392e-08  8.832946e-09
#            GOOGL     2.166833e-04  1.062717e-04  3.613799e-05  1.486960e-05
#            MCD       1.062717e-04  1.489226e-04  4.260056e-05  3.795386e-05
#            NKE       3.613799e-05  4.260056e-05  1.084582e-04  1.967174e-05
#            USDOLLAR  1.486960e-05  3.795386e-05  1.967174e-05  2.299815e-04
# 2018-03-21 AMZN      9.938860e-09 -7.274711e-09 -1.276429e-08  9.735538e-09
#            GOOGL     3.790390e-09
#            MCD      -1.452574e-08
#            NKE      -1.526278e-08
#            USDOLLAR  4.984624e-09
# 2018-03-26 AMZN      1.089637e-10
#            GOOGL     7.402813e-09
#            MCD      -1.182069e-08
#            NKE      -1.342887e-08
#            USDOLLAR  6.305083e-09
# 2018-03-27 AMZN      1.103604e-10
#            GOOGL     4.171120e-09
#            MCD      -1.597689e-08
#            NKE      -1.390047e-08
#            USDOLLAR  7.338515e-09
#
# [2800 rows x 5 columns]

# %%
r_hat = returns.rolling(window=250, min_periods=250).mean().shift(1).dropna()
Sigma_hat = returns.rolling(window=250, min_periods=250).cov().shift(1,0,0).dropna()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-4-7b40c55810b4> in <module>()
#       1 r_hat = returns.rolling(window=250, min_periods=250).mean().shift(1).dropna()
# ----> 2 Sigma_hat = returns.rolling(window=250, min_periods=250).cov().shift(1,0,0).dropna()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in shift(self, periods, freq, axis)
#    3038     def shift(self, periods=1, freq=None, axis=0):
#    3039         return super(DataFrame, self).shift(periods=periods, freq=freq,
# -> 3040                                             axis=axis)
#    3041
#    3042     def set_index(self, keys, drop=True, append=False, inplace=False,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in shift(self, periods, freq, axis)
#    6186             new_data = self._data.shift(periods=periods, axis=block_axis)
#    6187         else:
# -> 6188             return self.tshift(periods, freq)
#    6189
#    6190         return self._constructor(new_data).__finalize__(self)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in tshift(self, periods, freq, axis)
#    6279         else:
#    6280             new_data = self._data.copy()
# -> 6281             new_data.axes[block_axis] = index.shift(periods, freq)
#    6282
#    6283         return self._constructor(new_data).__finalize__(self)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in shift(self, periods, freq)
#    2131         """
#    2132         raise NotImplementedError("Not supported for type %s" %
# -> 2133                                   type(self).__name__)
#    2134
#    2135     def argsort(self, *args, **kwargs):
#
# NotImplementedError: Not supported for type MultiIndex

# %%
tcost_model=cp.TcostModel(half_spread=10E-4)
hcost_model=cp.HcostModel(borrow_costs=1E-4)

risk_model = cp.FullSigma(Sigma_hat)
gamma_risk, gamma_trade, gamma_hold = 5., 1., 1.
leverage_limit = cp.LeverageLimit(3)

spo_policy = cp.SinglePeriodOpt(return_forecast=r_hat, 
                                costs=[gamma_risk*risk_model, gamma_trade*tcost_model, gamma_hold*hcost_model],
                                constraints=[leverage_limit])

# %% [markdown]
# ### Compute optimal trades

# %%
current_portfolio=pd.Series(index=r_hat.columns,data=0)
current_portfolio.USDOLLAR=10000

shares_to_trade=spo_policy.get_rounded_trades(current_portfolio, prices, t=pd.datetime.today())
shares_to_trade
# Out:
# AMZN     2.0
# GOOGL    0.0
# MCD      0.0
# NKE     -0.0
# dtype: float64

# %% [markdown]
# #### Export to Excel file

# %%
pd.DataFrame({pd.datetime.today().date().__str__():shares_to_trade}).to_excel('shares_to_trade.xls')
